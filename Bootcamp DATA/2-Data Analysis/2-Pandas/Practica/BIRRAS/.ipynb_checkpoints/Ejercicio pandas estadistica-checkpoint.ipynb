# %% [markdown]
# ![imagen](https://cdn.foodbeast.com/content/wp-content/uploads/2012/03/beer-print-01-selectism.jpg)
#
# # Ejercicio pandas estadistica
# Para este ejercicio se ha utilizado [un dataset de un concurso de kaggle](https://www.kaggle.com/nickhould/craft-cans), cuyo reto consiste en predecir el tipo de cerveza en función de sus características (nivel de alcohol, amargura, tamaño...).
#
# # Ejercicio 1
# Importa las librerias que consideres

# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns

# %% [markdown]
# ## Ejercicio 2
# 1. Importa el dataset "datasets_beer.csv"
# 2. Imprime por pantalla los primeros registros.
# 3. ¿Cuáles son sus columnas?
# 4. ¿Qué dimensiones tiene el DataFrame?

# %%
# 1.
data = pd.read_csv('datasets_beers.csv')


# 2.
data.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
# 3.
data.columns
# Out:
# Index(['Unnamed: 0', 'abv', 'ibu', 'id', 'name', 'style', 'brewery_id',
#        'ounces'],
#       dtype='object')

# %%
# 4.
data.ndim
# Out:
# 2

# %% [markdown]
# ## Ejercicio 3
# [Elimina la columna "Unnamed: 0"](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
data.pop('Unnamed: 0')
data.columns
# Out:
# Index(['abv', 'ibu', 'id', 'name', 'style', 'brewery_id', 'ounces'], dtype='object')

# %% [markdown]
# ## Ejercicio 4
# ¿Cuántas filas y columnas tiene el dataset?

# %%
data.shape
# Out:
# (2410, 7)

# %% [markdown]
# ## Ejercicio 5
# ¿De qué tipo son los datos?

# %%
data.dtypes
# Out:
# abv           float64
# ibu           float64
# id              int64
# name           object
# style          object
# brewery_id      int64
# ounces        float64
# dtype: object

# %% [markdown]
# ## Ejercicio 6
# Obtén en una nuevo DataFrame un resumen con las principales estadísticas de las columnas numércias: mean, max, count, cuantiles...

# %%
data.describe()
# Out:
#                abv          ibu           id   brewery_id       ounces
# count  2348.000000  1405.000000  2410.000000  2410.000000  2410.000000
# mean      0.059773    42.713167  1431.113278   231.749793    13.592241
# std       0.013542    25.954066   752.459975   157.685604     2.352204
# min       0.001000     4.000000     1.000000     0.000000     8.400000
# 25%       0.050000    21.000000   808.250000    93.000000    12.000000
# 50%       0.056000    35.000000  1453.500000   205.000000    12.000000
# 75%       0.067000    64.000000  2075.750000   366.000000    16.000000
# max       0.128000   138.000000  2692.000000   557.000000    32.000000

# %% [markdown]
# ## Ejercicio 7
# ¿Cuántas birras hay de cada estilo en este dataset? [Investiga en la documentación de Series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html) si puedes hacer un conteo de valores.

# %%
data['style'].nunique()
# Out:
# 99

# %% [markdown]
# ## Ejercicio 8
# 1. Imprime por pantalla los registros del 10 al 20
# 2. De esos registros, imprime por pantalla desde la columna `name` a `ounces`, ambas incluidas
# 3. Quédate con las columnas `abv`, `ibu` y `ounces`, y además quédate sólo con los registros 10 al 20.
# 4. Convierte el resultado del apartado 3 en un array de `numpy`

# %%
data.iloc[10:21]
# Out:
#       abv   ibu    id                          name                    style  \
# 10  0.072   NaN  2099             Sophomoric Saison   Saison / Farmhouse Ale
# 11  0.073   NaN  2098         Regional Ring Of Fire   Saison / Farmhouse Ale
# 12  0.069   NaN  2097                    Garce Selé   Saison / Farmhouse Ale
# 13  0.085   NaN  1980               Troll Destroyer              Belgian IPA
# 14  0.061  60.0  1979                  Bitter Bitch  American Pale Ale (APA)
# 15  0.060   NaN  2318                   Ginja Ninja                    Cider
# 16  0.060   NaN  2170                 Cherried Away                    Cider
# 17  0.060   NaN  2169                  Rhubarbarian                    Cider
# 18  0.060   NaN  1502                   BrightCider                    Cider
# 19  0.082   NaN  1593   He Said Baltic-Style Porter            Baltic Porter
# 20  0.082   NaN  1592  He Said Belgian-Style Tripel                   Tripel
#
#     brewery_id  ounces
# 10         177    12.0
# 11         177    12.0
# 12         177    12.0
# 13         177    12.0
# 14         177    12.0
# 15         154    12.0
# 16         154    12.0
# 17         154    12.0
# 18         154    12.0
# 19         368    12.0
# 20         368    12.0

# %%
data.loc[10:21, 'name':'ounces']
# Out:
#                             name                    style  brewery_id  ounces
# 10             Sophomoric Saison   Saison / Farmhouse Ale         177    12.0
# 11         Regional Ring Of Fire   Saison / Farmhouse Ale         177    12.0
# 12                    Garce Selé   Saison / Farmhouse Ale         177    12.0
# 13               Troll Destroyer              Belgian IPA         177    12.0
# 14                  Bitter Bitch  American Pale Ale (APA)         177    12.0
# 15                   Ginja Ninja                    Cider         154    12.0
# 16                 Cherried Away                    Cider         154    12.0
# 17                  Rhubarbarian                    Cider         154    12.0
# 18                   BrightCider                    Cider         154    12.0
# 19   He Said Baltic-Style Porter            Baltic Porter         368    12.0
# 20  He Said Belgian-Style Tripel                   Tripel         368    12.0
# 21                 Lower De Boom      American Barleywine         368     8.4

# %%
data.iloc[10:21][['abv', 'ibu', 'ounces']]
# Out:
#       abv   ibu  ounces
# 10  0.072   NaN    12.0
# 11  0.073   NaN    12.0
# 12  0.069   NaN    12.0
# 13  0.085   NaN    12.0
# 14  0.061  60.0    12.0
# 15  0.060   NaN    12.0
# 16  0.060   NaN    12.0
# 17  0.060   NaN    12.0
# 18  0.060   NaN    12.0
# 19  0.082   NaN    12.0
# 20  0.082   NaN    12.0

# %%
data.iloc[10:21][['abv', 'ibu', 'ounces']].values
# Out:
# array([[ 0.072,    nan, 12.   ],
#        [ 0.073,    nan, 12.   ],
#        [ 0.069,    nan, 12.   ],
#        [ 0.085,    nan, 12.   ],
#        [ 0.061, 60.   , 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.06 ,    nan, 12.   ],
#        [ 0.082,    nan, 12.   ],
#        [ 0.082,    nan, 12.   ]])

# %% [markdown]
# ## Ejercicio 9
# ¿Cuántas onzas pesan todas las birras del dataset?

# %%
data['ounces'].sum()
# Out:
# 32757.3

# %% [markdown]
# ## Ejercicio 10
# El amargor de las cervezas se mide por su nivel de IBUs.
# 1. ¿Cuál es el amargor medio de las cervezas?
# 2. ¿El máximo? ¿Y el mínimo?
# 3. ¿Qué cerveza es la que tiene el amargor máximo? ¿Cuál es la de amargor mínimo?

# %%
data['ibu'].mean()
# Out:
# 42.71316725978647

# %%
data['ibu'].max()
# Out:
# 138.0

# %%
data['ibu'].min()
# Out:
# 4.0

# %%
data[data['ibu'] == [data['ibu'].max()]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-6251250702f8> in <module>
# ----> 1 data[data['ibu'] == [data['ibu'].max()]]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      27     @unpack_zerodim_and_defer("__eq__")
#      28     def __eq__(self, other):
# ---> 29         return self._cmp_method(other, operator.eq)
#      30
#      31     @unpack_zerodim_and_defer("__ne__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    4976         rvalues = extract_array(other, extract_numpy=True)
#    4977
# -> 4978         res_values = ops.comparison_op(lvalues, rvalues, op)
#    4979
#    4980         return self._construct_result(res_values, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     221         #  The ambiguous case is object-dtype.  See GH#27803
#     222         if len(lvalues) != len(rvalues):
# --> 223             raise ValueError(
#     224                 "Lengths must match to compare", lvalues.shape, rvalues.shape
#     225             )
#
# ValueError: ('Lengths must match to compare', (2410,), (1,))

# %%
data[['ibu', 'name']].min() #no
# Out:
# ibu                         4.0
# name    #001 Golden Amber Lager
# dtype: object

# %% [markdown]
# ## Ejercicio 11
# No queda muy claro cuánto de dispar, de dispersa, es la medida de IBU. Mediante estadística descriptiva (una o dos métricas, sin gráficas), razona la dispersión de la variable IBU.

# %%
print("Desviacion estandar amargor cerveza:", round(data['ibu'].std(), 2))
print("Media del amargor de las cervezas: ", data['ibu'].mean())
print("Mediana del amargor de las cervezas: ", data['ibu'].median())
print("Maximo del amargor de las cervezas: ", data['ibu'].max())
print("Minimo del amargor de las cervezas : ", data['ibu'].min())
print("Claramente está disperso, viendo el max y el min se aprecia que hay outliers")
# Out:
# Desviacion estandar amargor cerveza: 25.95
# Media del amargor de las cervezas:  42.71316725978647
# Mediana del amargor de las cervezas:  35.0
# Maximo del amargor de las cervezas:  138.0
# Minimo del amargor de las cervezas :  4.0
# Claramente está disperso, viendo el max y el min se aprecia que hay outliers

# %% [markdown]
# ## Ejercicio 12
# ¿Existe alguna relación lineal entre las variables numéricas del dataset? Intenta pintar este razonmiento mediante un gráfico

# %%
data.corr()
# Out:
#                  abv       ibu        id  brewery_id    ounces
# abv         1.000000  0.670621  0.042811   -0.098632  0.172529
# ibu         0.670621  1.000000  0.000485   -0.004875  0.054691
# id          0.042811  0.000485  1.000000   -0.504030  0.100843
# brewery_id -0.098632 -0.004875 -0.504030    1.000000 -0.133762
# ounces      0.172529  0.054691  0.100843   -0.133762  1.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),vmin=-1, vmax=1, center=0,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True, linewidths=.5);

# %% [markdown]
# ## Ejercicio 13
# Representa el nivel de alcohol (columna `abv`) en un histograma. ¿Se trata de una distribución simétrica o asimétrica?

# %%
sns.histplot(data['abv'], bins = 50);

# %%
'asimetria positiva'
# Out:
# 'asimetria positiva'

# %% [markdown]
# ## Ejercicio 14
# Representa mediante un *boxplot* de `seaborn` la variable `abv`

# %%
sns.boxplot(data['abv'])
# Out:
# C:\Users\angel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='abv'>

# %% [markdown]
# ## Ejercicio 15
# 1. ¿Qué estilos son los que tienen en media más alcohol?
# 2. ¿Y los estilos que son en media más amargos?

# %%
data.groupby('style')['abv'].mean().sort_values(ascending=False).head()
# Out:
# style
# English Barleywine        0.107667
# Quadrupel (Quad)          0.104000
# American Barleywine       0.099000
# American Malt Liquor      0.099000
# Russian Imperial Stout    0.097636
# Name: abv, dtype: float64

# %%
data.groupby('style')['ibu'].mean().sort_values(ascending=False).head()
# Out:
# style
# American Barleywine                   96.00
# American Double / Imperial IPA        93.32
# Russian Imperial Stout                86.50
# American Double / Imperial Pilsner    85.00
# Belgian Strong Dark Ale               72.00
# Name: ibu, dtype: float64

# %% [markdown]
# ## Ejercicio 16
# Carga el datasets de cervecerias `datasets_breweries.csv`

# %%
data1 = pd.read_csv('datasets_breweries.csv')
data1.head()
# Out:
#    Unnamed: 0                       name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %% [markdown]
# ## Ejercicio 17
# 1. Renombra la columna `Unnamed: 0` como `brewery_id`
# 2. Renombra tb la columna `name` por `brewery_name`. ¿Puedes hacer ambos apartados en una sola sentencia?

# %%
data1 = data1.rename(columns={'Unnamed: 0' : 'brewery_id',
                             'name': 'brewery_name'})
data1
# Out:
#      brewery_id                   brewery_name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 18
# Junta los dos datasets que tienes

# %%
data1 = data1.merge(data)
data1
# Out:
#       brewery_id                   brewery_name           city state    abv  \
# 0              0             NorthGate Brewing     Minneapolis    MN  0.045
# 1              0             NorthGate Brewing     Minneapolis    MN  0.049
# 2              0             NorthGate Brewing     Minneapolis    MN  0.048
# 3              0             NorthGate Brewing     Minneapolis    MN  0.060
# 4              0             NorthGate Brewing     Minneapolis    MN  0.060
# ...          ...                            ...            ...   ...    ...
# 2405         556        Butternuts Beer and Ale  Garrattsville    NY  0.049
# 2406         556        Butternuts Beer and Ale  Garrattsville    NY  0.068
# 2407         556        Butternuts Beer and Ale  Garrattsville    NY  0.049
# 2408         556        Butternuts Beer and Ale  Garrattsville    NY  0.043
# 2409         557  Sleeping Lady Brewing Company      Anchorage    AK  0.049
#
#        ibu    id                       name                    style  ounces
# 0     50.0  2692               Get Together             American IPA    16.0
# 1     26.0  2691              Maggie's Leap       Milk / Sweet Stout    16.0
# 2     19.0  2690                 Wall's End        English Brown Ale    16.0
# 3     38.0  2689                    Pumpion              Pumpkin Ale    16.0
# 4     25.0  2688                 Stronghold          American Porter    16.0
# ...    ...   ...                        ...                      ...     ...
# 2405   NaN    52   Heinnieweisse Weissebier               Hefeweizen    12.0
# 2406   NaN    51            Snapperhead IPA             American IPA    12.0
# 2407   NaN    50          Moo Thunder Stout       Milk / Sweet Stout    12.0
# 2408   NaN    49          Porkslap Pale Ale  American Pale Ale (APA)    12.0
# 2409   NaN    30  Urban Wilderness Pale Ale         English Pale Ale    12.0
#
# [2410 rows x 10 columns]

# %% [markdown]
# ## Ejercicio 19
# 1. ¿Cuántos estados diferentes hay?
# 2. ¿Y ciudades diferentes?
# 3. ¿Cuántas vervecerías hay?

# %%
print(data1['state'].nunique())
print(data1['city'].nunique())
print(data1['brewery_id'].nunique())
# Out:
# 51
# 384
# 558

# %% [markdown]
# ## Ejercicio 20
# Agrupa por estado y ciudad, la media, mediana y máximo nivel de alcohol

# %%
data1.groupby(['state', 'city']).aggregate(['mean', 'median', max])['abv']
# Out:
#                       mean  median    max
# state city
#  AK   Anchorage   0.054200  0.0520  0.063
#       Juneau      0.053000  0.0530  0.053
#       Soldotna    0.058500  0.0580  0.068
#       Talkeetna   0.059500  0.0585  0.065
#  AL   Birmingham  0.065400  0.0600  0.093
# ...                    ...     ...    ...
#  WI   Wilson      0.055000  0.0550  0.055
#  WV   Lewisburg   0.062000  0.0620  0.067
#  WY   Jackson     0.054857  0.0520  0.068
#       Pinedale    0.061000  0.0610  0.072
#       Sheridan    0.052833  0.0480  0.070
#
# [401 rows x 3 columns]

# %% [markdown]
# ## Ejercicio 21
# ¿Cuáles son las cervezas más amargas que se consumen en Indiana, estado = `IN`?

# %%
bitter_ind = data1[data1['state'] == ' IN']
bitter_ind.sort_values(['ibu'], ascending = False)[['name', 'ibu', 'state']]
# Out:
#                        name    ibu state
# 145   Overlord Imperial IPA  115.0    IN
# 166        Hopkick Dropkick  115.0    IN
# 140          Half Cycle IPA  104.0    IN
# 203                    Isis   91.0    IN
# 143                    Csar   90.0    IN
# ...                     ...    ...   ...
# 1628          Floyd's Folly    NaN    IN
# 1629         Half Court IPA    NaN    IN
# 1727       Leprechaun Lager    NaN    IN
# 1754           Lift Off IPA    NaN    IN
# 2289     T-6 Red Ale (2004)    NaN    IN
#
# [139 rows x 3 columns]

# %% [markdown]
# ## Ejercicio 22
# Obtén una tabla con los principales estadísticos del campo `ibu`,  a nivel ciudad

# %%
data1.groupby(['city', 'state'])['ibu'].describe()
# Out:
#                       count        mean        std    min     25%    50%  \
# city           state
# Abingdon        VA      1.0  135.000000        NaN  135.0  135.00  135.0
# Abita Springs   LA      3.0   27.333333  21.455380   13.0   15.00   17.0
# Ada             MI      0.0         NaN        NaN    NaN     NaN    NaN
# Afton           VA      4.0   43.000000  19.899749   22.0   28.00   45.0
# Airway Heights  WA      0.0         NaN        NaN    NaN     NaN    NaN
# ...                     ...         ...        ...    ...     ...    ...
# Woodinville     WA      4.0   46.750000  18.643587   27.0   39.75   44.0
# Worcester       MA      1.0   69.000000        NaN   69.0   69.00   69.0
# Yakima          WA      2.0   54.000000  22.627417   38.0   46.00   54.0
# Yardley         PA      0.0         NaN        NaN    NaN     NaN    NaN
# York            PA      4.0   44.250000  22.779742   20.0   35.00   41.0
#
#                          75%    max
# city           state
# Abingdon        VA    135.00  135.0
# Abita Springs   LA     34.50   52.0
# Ada             MI       NaN    NaN
# Afton           VA     60.00   60.0
# Airway Heights  WA       NaN    NaN
# ...                      ...    ...
# Woodinville     WA     51.00   72.0
# Worcester       MA     69.00   69.0
# Yakima          WA     62.00   70.0
# Yardley         PA       NaN    NaN
# York            PA     50.25   75.0
#
# [401 rows x 8 columns]

# %% [markdown]
# ## Ejercicio 23
# Consigue en un DataFrame todas las cervezas en cuyas cervecerías el mínimo nivel de `abv` sea de 0.07.

# %%
def filter(x):
    return x['abv'].min() >= 0.07
data1.groupby('brewery_name').filter(filter)
# Out:
#       brewery_id                        brewery_name                city  \
# 150           18              Black Acre Brewing Co.        Indianapolis
# 152           20                  Bare Hands Brewery             Granger
# 224           28              Taxman Brewing Company        Bargersville
# 285           39            Gonzo's BiggDogg Brewing           Kalamazoo
# 444           64            SlapShot Brewing Company             Chicago
# 445           64            SlapShot Brewing Company             Chicago
# 624           99  Christian Moerlein Brewing Company          Cincinnati
# 1097         180          Frog Level Brewing Company         Waynesville
# 1219         208              Kalona Brewing Company              Kalona
# 1220         208              Kalona Brewing Company              Kalona
# 1308         231         Borderlands Brewing Company              Tucson
# 1410         260      Mountain Town Brewing Company       Mount Pleasant
# 1455         274                    Portside Brewery           Cleveland
# 1583         304                  Blue Hills Brewery              Canton
# 1585         306               Beach Brewing Company      Virginia Beach
# 1643         322                      Voodoo Brewery           Meadville
# 1644         322                      Voodoo Brewery           Meadville
# 1645         322                      Voodoo Brewery           Meadville
# 1646         322                      Voodoo Brewery           Meadville
# 1647         322                      Voodoo Brewery           Meadville
# 1648         322                      Voodoo Brewery           Meadville
# 1740         354                     Kulshan Brewery          Bellingham
# 1754         358           Daredevil Brewing Company         Shelbyville
# 1871         376           RoughTail Brewing Company        Midwest City
# 1872         376           RoughTail Brewing Company        Midwest City
# 1873         376           RoughTail Brewing Company        Midwest City
# 2031         421                    Redstone Meadery             Boulder
# 2032         421                    Redstone Meadery             Boulder
# 2033         421                    Redstone Meadery             Boulder
# 2059         429               Asher Brewing Company             Boulder
# 2066         432                   Seabright Brewery          Santa Cruz
# 2174         465                   Engine 15 Brewing  Jacksonville Beach
# 2249         494                Seven Brides Brewery           Silverton
# 2250         494                Seven Brides Brewery           Silverton
# 2296         509                     Wingman Brewers              Tacoma
# 2297         509                     Wingman Brewers              Tacoma
#
#      state    abv    ibu    id                                     name  \
# 150     IN  0.072   75.0  2620                           Saucy Intruder
# 152     IN  0.070   46.0  2618                                 Thai.p.a
# 224     IN  0.080   22.0  2601                                Deduction
# 285     MI  0.070   11.0  2587                           Vanilla Porter
# 444     IL  0.085    NaN  2537          Monkey Dancing On A Razor Blade
# 445     IL  0.082    NaN  2536                              Tripel Deke
# 624     OH  0.089  126.0  2440          Bay of Bengal Double IPA (2014)
# 1097    NC  0.070   73.0  2254                          Salamander Slam
# 1219    IA  0.071    NaN  2163                           Sucha Much IPA
# 1220    IA  0.075   24.0  2162            Lewbricator Wheat Dopplebock
# 1308    AZ  0.071   16.0  2062                              Noche Dulce
# 1410    MI  0.082    NaN  1952                              Train Wreck
# 1455    OH  0.099    NaN  1909                     Big Chuck Barleywine
# 1583    MA  0.080   80.0  1812                  Quarter Mile Double IPA
# 1585    VA  0.088  108.0  1806                      Hoptopus Double IPA
# 1643    PA  0.092   25.0  1770                        Voodoo Love Child
# 1644    PA  0.079   23.0  1769                  White Magick of the Sun
# 1645    PA  0.075   31.0  1730                   Wynona's Big Brown Ale
# 1646    PA  0.092   25.0  1729                                 Gran Met
# 1647    PA  0.073   85.0  1603                           Good Vibes IPA
# 1648    PA  0.075   85.0  1488                                 Pilzilla
# 1740    WA  0.080    NaN  1637  Bellingham Beer Week 2013 Collaboration
# 1754    IN  0.072    NaN  1623                             Lift Off IPA
# 1871    OK  0.076   78.0  1577                               12th Round
# 1872    OK  0.070   80.0  1576                            RoughTail IPA
# 1873    OK  0.080    NaN  1575                        Polar Night Stout
# 2031    CO  0.080    NaN  1375                       Nectar of the Hops
# 2032    CO  0.080    NaN  1374                          Sunshine Nectar
# 2033    CO  0.080    NaN  1373                   Black Raspberry Nectar
# 2059    CO  0.070   45.0  1322      Green Bullet Organic India Pale Ale
# 2066    CA  0.074   60.0  1302                      Blur India Pale Ale
# 2174    FL  0.070    NaN  1107              Nut Sack Imperial Brown Ale
# 2249    OR  0.070  105.0   918                         Frankenlou's IPA
# 2250    OR  0.070   55.0   917                 Becky's Black Cat Porter
# 2296    WA  0.074   83.0   762                                  Ace IPA
# 2297    WA  0.080   31.0   761                              P-51 Porter
#
#                                    style  ounces
# 150                             Rye Beer    16.0
# 152                         American IPA    16.0
# 224                               Dubbel    12.0
# 285                      American Porter    16.0
# 444                          Belgian IPA    24.0
# 445                               Tripel    24.0
# 624       American Double / Imperial IPA    12.0
# 1097                        American IPA    16.0
# 1219                        American IPA    12.0
# 1220                          Doppelbock    12.0
# 1308                     American Porter    16.0
# 1410            American Amber / Red Ale    16.0
# 1455                 American Barleywine    12.0
# 1583      American Double / Imperial IPA    12.0
# 1585      American Double / Imperial IPA    16.0
# 1643                              Tripel    12.0
# 1644                             Witbier    12.0
# 1645                  American Brown Ale    12.0
# 1646             Belgian Strong Pale Ale    12.0
# 1647                        American IPA    12.0
# 1648  American Double / Imperial Pilsner    12.0
# 1740             Belgian Strong Dark Ale    16.0
# 1754                        American IPA    16.0
# 1871                 American Strong Ale    16.0
# 1872                        American IPA    16.0
# 1873                      American Stout    16.0
# 2031                                Mead    16.0
# 2032                                Mead    16.0
# 2033                                Mead    16.0
# 2059                        American IPA    16.0
# 2066                        American IPA    12.0
# 2174                  American Brown Ale    12.0
# 2249                        American IPA    16.0
# 2250                     American Porter    16.0
# 2296                        American IPA    16.0
# 2297                     American Porter    16.0

# %% [markdown]
# ## Ejercicio 24
# Teniendo en cuenta la media de amargor de todas las cervezas, obtén una tabla con las cervezas cuyos estados tengan una media de amargor en cerveza por encima de la media

# %%
mean_tot = data1['ibu'].mean()
print(mean_tot)
def filter(x):
    return x['ibu'].mean() >= mean_tot
data1.groupby('state').filter(filter)
# Out:
# 42.71316725978647
#       brewery_id             brewery_name           city state    abv   ibu  \
# 0              0       NorthGate Brewing     Minneapolis    MN  0.045  50.0
# 1              0       NorthGate Brewing     Minneapolis    MN  0.049  26.0
# 2              0       NorthGate Brewing     Minneapolis    MN  0.048  19.0
# 3              0       NorthGate Brewing     Minneapolis    MN  0.060  38.0
# 4              0       NorthGate Brewing     Minneapolis    MN  0.060  25.0
# ...          ...                      ...            ...   ...    ...   ...
# 2404         555    Ukiah Brewing Company          Ukiah    CA  0.055   NaN
# 2405         556  Butternuts Beer and Ale  Garrattsville    NY  0.049   NaN
# 2406         556  Butternuts Beer and Ale  Garrattsville    NY  0.068   NaN
# 2407         556  Butternuts Beer and Ale  Garrattsville    NY  0.049   NaN
# 2408         556  Butternuts Beer and Ale  Garrattsville    NY  0.043   NaN
#
#         id                      name                    style  ounces
# 0     2692              Get Together             American IPA    16.0
# 1     2691             Maggie's Leap       Milk / Sweet Stout    16.0
# 2     2690                Wall's End        English Brown Ale    16.0
# 3     2689                   Pumpion              Pumpkin Ale    16.0
# 4     2688                Stronghold          American Porter    16.0
# ...    ...                       ...                      ...     ...
# 2404    98             Pilsner Ukiah          German Pilsener    12.0
# 2405    52  Heinnieweisse Weissebier               Hefeweizen    12.0
# 2406    51           Snapperhead IPA             American IPA    12.0
# 2407    50         Moo Thunder Stout       Milk / Sweet Stout    12.0
# 2408    49         Porkslap Pale Ale  American Pale Ale (APA)    12.0
#
# [1288 rows x 10 columns]
