# %%
import pandas as pd
import numpy as np

df = pd.read_csv('2016 School Explorer.csv')
df
# Out:
#      Adjusted Grade New? Other Location Code in LCGMS  \
# 0               NaN  NaN                          NaN
# 1               NaN  NaN                          NaN
# 2               NaN  NaN                          NaN
# 3               NaN  NaN                          NaN
# 4               NaN  NaN                          NaN
# ...             ...  ...                          ...
# 1267            NaN  NaN                          NaN
# 1268            NaN  NaN                          NaN
# 1269            NaN  NaN                          NaN
# 1270            NaN  NaN                          NaN
# 1271            NaN  NaN                          NaN
#
#                                    School Name      SED Code Location Code  \
# 0                    P.S. 015 ROBERTO CLEMENTE  310100010015        01M015
# 1                          P.S. 019 ASHER LEVY  310100010019        01M019
# 2                         P.S. 020 ANNA SILVER  310100010020        01M020
# ...

# %%
df.iloc[:, 15:]
# Out:
#      Community School?  Economic Need Index School Income Estimate  \
# 0                  Yes                0.919            $31,141.72
# 1                   No                0.641            $56,462.88
# 2                   No                0.744            $44,342.61
# 3                   No                0.860            $31,454.00
# 4                   No                0.730            $46,435.59
# ...                ...                  ...                    ...
# 1267                No                0.832            $27,243.69
# 1268                No                0.825            $24,172.46
# 1269                No                0.724            $26,422.05
# 1270                No                0.544            $47,192.42
# 1271                No                0.840            $29,096.71
#
#      Percent ELL Percent Asian Percent Black Percent Hispanic  \
# 0             9%            5%           32%              60%
# ...
